# %% [markdown]
# ## Examples of using IVHD
#
# To execute this notebook IVHD must be installed in your python environment.
#
# #### Local installation
# To install `ivhd` package in editable mode run `pip install -e .` in base directory of this repository.
#
# #### PyPI installation
# To install `ivhd` package from PyPI run `pip install ivhd`

# %%
import os
import sys
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

from ivhd.ivhd import IVHD
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

dataset = load_digits()
dataset
X = dataset["data"]
y = dataset["target"]
X = X / 255.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from .ivhd import ivhd
#       2 from sklearn.datasets import load_digits
#       3 from sklearn.decomposition import PCA
#
# ImportError: attempted relative import with no known parent package

# %%
pca = PCA()
X_pca = pca.fit_transform(X)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, s=2)

# %%
tsne = TSNE()
X_tsne = tsne.fit_transform(X)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, s=2)

# %%
ivhd = IVHD(simulation_steps=1000, nn=5, rn=2, lambda_=0.95, c=0.05)
X_ivhd = ivhd.fit_transform(X)
plt.scatter(X_ivhd[:, 0], X_ivhd[:, 1], c=y, s=2)

# %%
ivhd_grad = IVHDGrad(steps=2000, nn=5, rn=2, re_draw_remote_neighbors=True, optimizer_params={"lr": 0.005})
X_ivhd_grad = ivhd_grad.fit_transform(X)
plt.scatter(X_ivhd_grad[:, 0], X_ivhd_grad[:, 1], c=y, s=2)

# %%
plt.show()

# %%
import sys
sys.path.append("../FIt-SNE/")

# %%
from fast_tsne import fast_tsne

# %%
# fitsne = fast_tsne()
# X_fitsne = fitsne.fit_transform(X)
X_fitsne = fast_tsne(X)
plt.scatter(X_fitsne[:, 0], X_fitsne[:, 1], c=y, s=2)
# Out:
# =============== t-SNE v1.2.1 ===============
# fast_tsne data_path: data_2024-12-11 21:20:55.672198-646162272.dat
# fast_tsne result_path: result_2024-12-11 21:20:55.672198-646162272.dat
# fast_tsne nthreads: 12
# Read the following parameters:
# 	 n 1797 by d 64 dataset, theta 0.500000,
# 	 perplexity 30.000000, no_dims 2, max_iter 750,
# 	 stop_lying_iter 250, mom_switch_iter 250,
# 	 momentum 0.500000, final_momentum 0.800000,
# 	 learning_rate 200.000000, max_step_norm 5.000000,
# 	 K -1, sigma -1.000000, nbody_algo 2,
# 	 knn_algo 1, early_exag_coeff 12.000000,
# 	 no_momentum_during_exag 0, n_trees 50, search_k 4500,
# 	 start_late_exag_iter -1, late_exag_coeff -1.000000
# 	 nterms 3, interval_per_integer 1.000000, min_num_intervals 50, t-dist df 1.000000
# Read the 1797 x 64 data matrix successfully. X[0,0] = 0.000000
# Read the initialization successfully.
# Will use momentum during exaggeration phase
# Computing input similarities...
# ...
